# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('survey_data.csv')
df1.head()
# Out:
#    id         city  gender    age  hh_size        hh_type  \
# 0   1  Montpellier    male  25-34        2         couple
# 1   2  Montpellier  female  25-34        2         couple
# 2   3         Lyon  female  25-34        2         couple
# 3   4         Lyon    male  25-34        3  single parent
# 4   5     Bordeaux    male  25-34        2         couple
#
#              education  height  weight  waist
# 0  master or doctorate   183.0    62.0   78.0
# 1          high school   163.0    60.0   75.0
# 2  master or doctorate   172.0    65.0   60.0
# 3             bachelor   182.0    85.0   95.0
# 4  master or doctorate   177.0    70.0   81.0

# %%
# Separating the data with semicoloms in order to make it compatible with the other csv file
df2 = pd.read_csv('steps_data.csv', sep = ';')
df2.head()
# Out:
#    id  20-06-13  21-06-13  22-06-13  23-06-13  24-06-13  25-06-13  26-06-13  \
# 0   1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   2       NaN       NaN       NaN       NaN       NaN     641.0    4045.0
# 2   3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   4       NaN       NaN      25.0    4067.0    7192.0     154.0    8674.0
# 4   5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    27-06-13  28-06-13    ...     04-05-14  05-05-14  06-05-14  07-05-14  \
# 0       NaN       NaN    ...          NaN       NaN       NaN       NaN
# 1    2310.0    2480.0    ...          NaN       NaN       NaN       NaN
# 2       NaN       NaN    ...          NaN       NaN       NaN       NaN
# 3    8275.0     850.0    ...          NaN       NaN       NaN       NaN
# 4       NaN       NaN    ...          NaN       NaN       NaN       NaN
#
#    08-05-14  09-05-14  10-05-14  11-05-14  12-05-14  13-05-14
# ...

# %%
# Looking for commong identifier to merge both files into a new dataframe
df3 = pd.merge(df1, df2, on = 'id')
df3.head()
# Out:
#    id         city  gender    age  hh_size        hh_type  \
# 0   1  Montpellier    male  25-34        2         couple
# 1   2  Montpellier  female  25-34        2         couple
# 2   3         Lyon  female  25-34        2         couple
# 3   4         Lyon    male  25-34        3  single parent
# 4   5     Bordeaux    male  25-34        2         couple
#
#              education  height  weight  waist    ...     04-05-14  05-05-14  \
# 0  master or doctorate   183.0    62.0   78.0    ...          NaN       NaN
# 1          high school   163.0    60.0   75.0    ...          NaN       NaN
# 2  master or doctorate   172.0    65.0   60.0    ...          NaN       NaN
# 3             bachelor   182.0    85.0   95.0    ...          NaN       NaN
# 4  master or doctorate   177.0    70.0   81.0    ...          NaN       NaN
#
#    06-05-14  07-05-14  08-05-14  09-05-14  10-05-14  11-05-14  12-05-14  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df3.info('waist')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Data columns (total 338 columns):
# id           int64
# city         object
# gender       object
# age          object
# hh_size      int64
# hh_type      object
# education    object
# height       float64
# weight       float64
# waist        float64
# 20-06-13     float64
# 21-06-13     float64
# 22-06-13     float64
# 23-06-13     float64
# 24-06-13     float64
# 25-06-13     float64
# 26-06-13     float64
# 27-06-13     float64
# 28-06-13     float64
# 29-06-13     float64
# 30-06-13     float64
# 01-07-13     float64
# 02-07-13     float64
# 03-07-13     float64
# 04-07-13     float64
# 05-07-13     float64
# 06-07-13     float64
# 07-07-13     float64
# 08-07-13     float64
# 09-07-13     float64
# 10-07-13     float64
# 11-07-13     float64
# 12-07-13     float64
# 13-07-13     float64
# 14-07-13     float64
# 15-07-13     float64
# 16-07-13     float64
# 17-07-13     float64
# 18-07-13     float64
# ...

# %%
# Finding out what is plausible waist size, looking on domain knowledge
df3['waist'].value_counts()
# Out:
# 90.0     46
# 80.0     46
# 84.0     35
# 83.0     32
# 82.0     30
# 75.0     30
# 85.0     29
# 95.0     28
# 92.0     28
# 87.0     28
# 88.0     28
# 70.0     26
# 100.0    26
# 86.0     25
# 89.0     24
# 76.0     23
# 93.0     22
# 78.0     22
# 73.0     21
# 77.0     18
# 98.0     18
# 97.0     16
# 91.0     16
# 74.0     15
# 81.0     14
# 65.0     14
# 105.0    14
# 72.0     14
# 110.0    14
# 99.0     14
#          ..
# 63.0      2
# 125.0     2
# 61.0      2
# 64.0      2
# 122.0     2
# 115.0     2
# 132.0     2
# 58.0      2
# 41.0      2
# 117.0     1
# 0.0       1
# 116.0     1
# 173.0     1
# 175.0     1
# 119.0     1
# 27.0      1
# 44.0      1
# 130.0     1
# 55.0      1
# 56.0      1
# 46.0      1
# 49.0      1
# 48.0      1
# 172.0     1
# 53.0      1
# 131.0     1
# 36.0      1
# 39.0      1
# 35.0      1
# 147.0     1
# Name: waist, Length: 85, dtype: int64

# %%
def replace_value(x):
    if(x < 45.0):
        return float('NaN')
    else: 
        return x
    
df3['waist_corrected'] = df3['waist'].apply(replace_value)
df3
# Out:
#       id         city  gender    age  hh_size        hh_type  \
# 0      1  Montpellier    male  25-34        2         couple
# 1      2  Montpellier  female  25-34        2         couple
# 2      3         Lyon  female  25-34        2         couple
# 3      4         Lyon    male  25-34        3  single parent
# 4      5     Bordeaux    male  25-34        2         couple
# 5      6         Lyon    male  45-54        1         single
# 6      7     Bordeaux  female  25-34        1         single
# 7      8         Lyon  female  35-44        3  single parent
# 8      9     Bordeaux  female  25-34        3         family
# 9     10         Lyon  female  25-34        3         family
# 10    11         Lyon    male  55-64        2  single parent
# 11    12         Lyon  female  25-34        1         single
# 12    13         Lyon  female  45-54        3  single parent
# 13    14         Lyon  female  55-64        1         single
# ...
